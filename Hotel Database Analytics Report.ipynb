# %% [markdown]
# ![hote.PNG](attachment:hote.PNG)

# %% [markdown]
# ![bac.PNG](attachment:bac.PNG)

# %% [markdown]
# ![ov.PNG](attachment:ov.PNG)

# %% [markdown]
# ![0v11.PNG](attachment:0v11.PNG)

# %% [markdown]
# ![e.PNG](attachment:e.PNG)

# %% [markdown]
# ![er.PNG](attachment:er.PNG)

# %% [markdown]
# ![das.PNG](attachment:das.PNG)

# %% [markdown]
# ![dash.PNG](attachment:dash.PNG)

# %% [markdown]
# ![ob.PNG](attachment:ob.PNG)

# %% [markdown]
# ![ob1.PNG](attachment:ob1.PNG)

# %% [markdown]
# ![re.PNG](attachment:re.PNG)

# %% [markdown]
# ![re1.PNG](attachment:re1.PNG)
